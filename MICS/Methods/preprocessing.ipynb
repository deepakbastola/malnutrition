# %%
import pyreadstat
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_bh = pyreadstat.read_sav('/workspaces/malnutrition/MICS/bh.sav')[0]
df_hh = pyreadstat.read_sav('/workspaces/malnutrition/MICS/hh.sav')[0]
df_wm = pyreadstat.read_sav('/workspaces/malnutrition/MICS/wm.sav')[0]
df_fs = pyreadstat.read_sav('/workspaces/malnutrition/MICS/fs.sav')[0]
df_mn = pyreadstat.read_sav('/workspaces/malnutrition/MICS/mn.sav')[0]
df_hl = pyreadstat.read_sav('/workspaces/malnutrition/MICS/hl.sav')[0]
df_ch = pyreadstat.read_sav('/workspaces/malnutrition/MICS/ch.sav')[0] # Codespaces
data = pd.read_spss('/workspaces/malnutrition/MICS/ch.sav') # Codespaces

# df_ch = pd.read_spss('C:/Users/dbastola2022/OneDrive - Florida Atlantic University/Academics/Research/Malnutrition/MICS/ch.sav') # Office Local
# data = pd.read_spss('C:/Users/dbastola2022/OneDrive - Florida Atlantic University/Academics/Research/Malnutrition/MICS/ch.sav') # Office Local

# %%
df_ch.head()
# Out:
#    HH1  HH2   LN  UF1  UF2  UF3  UFINT  UF4    UF5    UF6  ...  wscoreu  \
# 0  1.0  3.0  5.0  1.0  3.0  5.0  103.0  4.0  103.0  100.0  ...      NaN
# 1  1.0  5.0  5.0  1.0  5.0  5.0  104.0  2.0  104.0  100.0  ...      NaN
# 2  1.0  6.0  5.0  1.0  6.0  5.0  102.0  2.0  102.0  100.0  ...      NaN
# 3  1.0  6.0  6.0  1.0  6.0  6.0  102.0  2.0  102.0  100.0  ...      NaN
# 4  1.0  7.0  4.0  1.0  7.0  4.0  103.0  2.0  103.0  100.0  ...      NaN
#
#    windex5u  windex10u   wscorer  windex5r  windex10r  ListCat  PSU  dstratum  \
# 0       NaN        NaN -0.831559       2.0        3.0      1.0  1.0      11.1
# 1       NaN        NaN -1.220021       1.0        2.0      1.0  1.0      11.1
# 2       NaN        NaN -0.681183       2.0        3.0      1.0  1.0      11.1
# 3       NaN        NaN -0.681183       2.0        3.0      1.0  1.0      11.1
# 4       NaN        NaN -1.308931       1.0        1.0      1.0  1.0      11.1
#
#    stratum
# 0      1.1
# 1      1.1
# 2      1.1
# 3      1.1
# 4      1.1
#
# [5 rows x 449 columns]

# %%
# df_bh.to_csv('/workspaces/malnutrition/MICS/df_ch.csv', index=False)

# %%
print(df_hl.shape)
print(df_bh.shape)
print(df_wm.shape)
print(df_hh.shape)
print(df_fs.shape)
print(df_ch.shape)
print(df_mn.shape)
# Out:
# (56595, 84)
# (27345, 53)
# (15019, 414)
# (12800, 471)
# (7824, 254)
# (6749, 449)
# (5605, 199)

# %%
# df1 = data[['AN4', 'AN8', 'BD2', 'UB9', 'CA1', 'CA14', 'HH6', 'HL4', 'melevel1', 'cinsurance', 'HH7c', 'windex5', 'WAZ2', 'HAZ2', 'WHZ2']]
# df1 = df1.rename(columns={
#     'AN4': 'child_age',
#     'AN8': 'child_weight',
#     'BD2': 'ever_breastfed',
#     'CA1': 'diarrhoea_last_2_weeks',
#     'CA14': 'fever_last_2_weeks',
#     'HH6': 'area',
#     'HL4': 'child_sex',
#     'melevel1': 'mother_education',
#     'cinsurance': 'health_insurance',
#     'HH7c': 'province',
#     'windex5': 'wealth_index',
#     'WAZ2': 'underweight',
#     'HAZ2': 'stunting',
#     'WHZ2': 'wasting'
# })
# df1.head()

# %%
df1 = df_ch[['AN4', 'AN8', 'BD2', 'CA1', 'CA14', 'HH6', 'HL4', 'melevel1', 'cinsurance', 'HH7c', 'windex5', 'WAZ2', 'HAZ2', 'WHZ2']]
df1 = df1.rename(columns={
    'AN4': 'child_age',
    'AN8': 'child_weight',
    'BD2': 'ever_breastfed',
    'CA1': 'diarrhoea_last_2_weeks',
    'CA14': 'fever_last_2_weeks',
    'HH6': 'area',
    'HL4': 'child_sex',
    'melevel1': 'mother_education',
    'cinsurance': 'health_insurance',
    'HH7c': 'province',
    'windex5': 'wealth_index',
    'WAZ2': 'underweight',
    'HAZ2': 'stunting',
    'WHZ2': 'wasting'
})
df1.head()
# Out:
#    child_age  child_weight  ever_breastfed  diarrhoea_last_2_weeks  \
# 0        1.0           7.8             1.0                     2.0
# 1        3.0          12.5             NaN                     2.0
# 2        2.0          11.1             1.0                     1.0
# 3        1.0           9.3             1.0                     1.0
# 4        4.0          14.7             NaN                     2.0
#
#    fever_last_2_weeks  area  child_sex  mother_education  health_insurance  \
# 0                 2.0   2.0        1.0               5.0               2.0
# 1                 1.0   2.0        1.0               5.0               2.0
# 2                 2.0   2.0        2.0               2.0               2.0
# 3                 1.0   2.0        2.0               2.0               2.0
# 4                 2.0   2.0        2.0               2.0               2.0
#
#    province  wealth_index  underweight  stunting  wasting
# 0       1.0           1.0        -2.94     -3.53    -1.69
# 1       1.0           1.0        -1.93     -2.58    -0.65
# 2       1.0           1.0        -1.45     -1.07    -1.27
# 3       1.0           1.0        -0.98     -0.90    -0.74
# 4       1.0           1.0        -1.35     -1.67    -0.45

# %%
coded_child_age = [99.6, 99.5, 99.4, 99.3]
coded_underweight = [99.99, 99.98, 99.97]
coded_stunting = [99.99, 99.98, 99.97]
coded_wasting = [99.97]
coded_diarrhoea = [9, 8]
coded_fever = [8]
coded_insurance = [9]
coded_breastfed = [9]

# Remove rows with coded entries in each column
df2 = df1.copy()
df2 = df2[~df2['child_age'].isin(coded_child_age)]
df2 = df2[~df2['underweight'].isin(coded_underweight)]
df2 = df2[~df2['stunting'].isin(coded_stunting)]
df2 = df2[~df2['wasting'].isin(coded_wasting)] 
df2 = df2[~df2['diarrhoea_last_2_weeks'].isin(coded_diarrhoea)]
df2 = df2[~df2['fever_last_2_weeks'].isin(coded_fever)]
df2 = df2[~df2['health_insurance'].isin(coded_insurance)]
df2 = df2[~df2['ever_breastfed'].isin(coded_breastfed)]

# df1.to_csv('/workspaces/malnutrition/MICS/df1.csv', index=False)

# %%
df2['underweight'] = [2 if -2 <= x < 2 else 1 for x in df2['underweight']]
df2['stunting'] = [2 if -2 <= x < 2 else 1 for x in df2['stunting']]
df2['wasting'] = [2 if -2 <= x < 2 else 1 for x in df2['wasting']]

# %%
df2.dropna(inplace=True)

# %%
df2.head()
# Out:
#    child_age  child_weight  ever_breastfed  diarrhoea_last_2_weeks  \
# 0        1.0           7.8             1.0                     2.0
# 2        2.0          11.1             1.0                     1.0
# 3        1.0           9.3             1.0                     1.0
# 5        0.0           6.9             1.0                     2.0
# 6        1.0          10.5             1.0                     2.0
#
#    fever_last_2_weeks  area  child_sex  mother_education  health_insurance  \
# 0                 2.0   2.0        1.0               5.0               2.0
# 2                 2.0   2.0        2.0               2.0               2.0
# 3                 1.0   2.0        2.0               2.0               2.0
# 5                 2.0   2.0        2.0               2.0               2.0
# 6                 2.0   2.0        1.0               5.0               2.0
#
#    province  wealth_index  underweight  stunting  wasting
# 0       1.0           1.0            1         1        2
# 2       1.0           1.0            2         2        2
# 3       1.0           1.0            2         2        2
# 5       1.0           1.0            2         2        2
# 6       1.0           1.0            2         2        2

# %%
sns.boxplot(x='underweight', y='child_weight',  data=df2)
plt.show()

# %% [markdown]
# ## Feature Importance Check for Categorical Features

# %% [markdown]
# ### Contingency table for categorical features

# %%
# Listing all categorical features
cat_columns = ['child_age', 'ever_breastfed', 'diarrhoea_last_2_weeks', 'fever_last_2_weeks', 'area', 'child_sex', 'mother_education', 'health_insurance', 'province', 'wealth_index']

# Contingency table for categorical features
contingency_tables = {}
for col in cat_columns:
    contingency_tables[col] = pd.crosstab(df2[col], df2['underweight'])
    print(f"Contingency table for {col}:\n{contingency_tables[col]}\n")
# Out:
# Contingency table for child_age:
# underweight    1    2
# child_age
# 0.0          175  877
# 1.0          320  949
# 2.0          337  923
#
# Contingency table for ever_breastfed:
# underweight       1     2
# ever_breastfed
# 1.0             780  2543
# 2.0              52   206
#
# Contingency table for diarrhoea_last_2_weeks:
# underweight               1     2
# diarrhoea_last_2_weeks
# 1.0                     130   306
# 2.0                     702  2443
#
# Contingency table for fever_last_2_weeks:
# underweight           1     2
# fever_last_2_weeks
# 1.0                 210   624
# 2.0                 622  2125
#
# Contingency table for area:
# underweight    1     2
# area
# 1.0          427  1541
# 2.0          405  1208
#
# Contingency table for child_sex:
# underweight    1     2
# child_sex
# 1.0          482  1437
# 2.0          350  1312
#
# Contingency table for mother_education:
# underweight         1     2
# mother_education
# 0.0               254   530
# 2.0               274   829
# 5.0               261  1137
# 8.0                42   252
# 9.0                 1     1
#
# Contingency table for health_insurance:
# underweight         1     2
# health_insurance
# 1.0                28   126
# 2.0               804  2623
#
# Contingency table for province:
# underweight    1    2
# province
# 1.0           93  437
# 2.0          164  375
# 3.0           93  572
# 4.0           52  356
# 5.0          156  396
# 6.0          134  295
# 7.0          140  318
#
# Contingency table for wealth_index:
# underweight     1    2
# wealth_index
# 1.0           313  735
# 2.0           159  572
# 3.0           166  545
# 4.0           129  515
# 5.0            65  382

# %% [markdown]
# ### $\chi^2$ Test

# %%
from scipy.stats import chi2_contingency

for col in cat_columns:
    contingency_table = contingency_tables[col]
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    print(f"Chi-square test for {col}:")
    print(f"Chi2: {chi2}, p-value: {p}, degrees of freedom: {dof}\n")
# Out:
# Chi-square test for child_age:
# Chi2: 37.19590962174061, p-value: 8.375502082606038e-09, degrees of freedom: 2
#
# Chi-square test for ever_breastfed:
# Chi2: 1.2973725369864069, p-value: 0.2546937182441599, degrees of freedom: 1
#
# Chi-square test for diarrhoea_last_2_weeks:
# Chi2: 11.644862319277589, p-value: 0.0006438009889408902, degrees of freedom: 1
#
# Chi-square test for fever_last_2_weeks:
# Chi2: 2.16862358399948, p-value: 0.14085225377966165, degrees of freedom: 1
#
# Chi-square test for area:
# Chi2: 5.594145723055967, p-value: 0.018020596857888465, degrees of freedom: 1
#
# Chi-square test for child_sex:
# Chi2: 7.998299618203107, p-value: 0.004682129803186619, degrees of freedom: 1
#
# Chi-square test for mother_education:
# Chi2: 68.84460899809002, p-value: 3.979787775733861e-14, degrees of freedom: 4
#
# Chi-square test for health_insurance:
# Chi2: 2.0162149608786426, p-value: 0.15562665071701554, degrees of freedom: 1
#
# Chi-square test for province:
# Chi2: 119.33770540251005, p-value: 2.2447401524337877e-23, degrees of freedom: 6
#
# Chi-square test for wealth_index:
# Chi2: 49.39529913285571, p-value: 4.82881402807429e-10, degrees of freedom: 4

# %% [markdown]
# ### Cramer's V Test
# $
# V = \sqrt{ \frac{\chi^2 / n}{\min(k - 1, r - 1)} }
# $

# %%
import numpy as np
cramers_v_results = {}

for col in cat_columns:
    if col != 'underweight':
        table = pd.crosstab(df2[col], df2['underweight'])
        chi2, _, _, _ = chi2_contingency(table)
        n = table.sum().sum()
        phi2 = chi2 / n
        r, k = table.shape
        dof = min(k - 1, r - 1)
        V = np.sqrt(phi2 / dof)

        cramers_v_results[col] = V
        print(f"{col}: Cramér's V = {V:.4f}")
# Out:
# child_age: Cramér's V = 0.1019
# ever_breastfed: Cramér's V = 0.0190
# diarrhoea_last_2_weeks: Cramér's V = 0.0570
# fever_last_2_weeks: Cramér's V = 0.0246
# area: Cramér's V = 0.0395
# child_sex: Cramér's V = 0.0473
# mother_education: Cramér's V = 0.1387
# health_insurance: Cramér's V = 0.0237
# province: Cramér's V = 0.1826
# wealth_index: Cramér's V = 0.1174

# %%
# Cramér's V values
cramers_v_df = pd.DataFrame.from_dict(cramers_v_results, orient='index', columns=['Cramér\'s V'])
cramers_v_df = cramers_v_df.sort_values(by='Cramér\'s V', ascending=False)
cramers_v_df.reset_index(inplace=True)
cramers_v_df.columns = ['Feature', 'Cramér\'s V']
cramers_v_df.to_csv('/workspaces/malnutrition/MICS/cramers_v_results.csv', index=False)
# Plotting Cramér's V values
plt.figure(figsize=(10, 6))
sns.barplot(x='Cramér\'s V', y='Feature', data=cramers_v_df)
plt.title("Cramér's V for Categorical Features vs Underweight")
plt.xlabel("Cramér's V")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.model_selection import train_test_split
df = df2.drop(columns=['stunting', 'wasting'])

X = df.drop(columns=['underweight'])
y = df['underweight']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Underweight', 'Underweight'], yticklabels=['Not Underweight', 'Underweight'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       0.73      0.42      0.53       167
#            2       0.84      0.95      0.89       550
#
#     accuracy                           0.83       717
#    macro avg       0.79      0.69      0.71       717
# weighted avg       0.82      0.83      0.81       717

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.metrics import PrecisionRecallDisplay

y_probas = model.predict_proba(X_test)[:, 1]

print(f'Average Precision: {average_precision_score(y_test, y_probas)}')
# Out:
# Average Precision: 0.16223346932610078

# %%
display = PrecisionRecallDisplay.from_estimator(
    model,
    X_test,
    y_test, 
    name="LogisticRegression",
    plot_chance_level = True,
)
display.ax_.set_title('2-class Precision Recall Curve')
plt.show()

# %% [markdown]
# ---

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, roc_auc_score
from collections import Counter
from imblearn.over_sampling import SMOTE
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from collections import Counter

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dropout(0.2))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['recall'])

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,  
    epochs=100,            
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)

test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_acc)

y_pred = model.predict(X_test).ravel()
y_pred_binary = (y_pred > 0.5).astype(int)

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_binary))
print("Classification Report:")
print(classification_report(y_test, y_pred_binary))
# Out:
# Epoch 1/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: -13.7268 - recall: 0.9983 - val_loss: -118.3069 - val_recall: 1.0000
# Epoch 2/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -254.2835 - recall: 1.0000 - val_loss: -900.1593 - val_recall: 1.0000
# Epoch 3/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -1367.4576 - recall: 1.0000 - val_loss: -3080.9343 - val_recall: 1.0000
# Epoch 4/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -4083.6003 - recall: 1.0000 - val_loss: -7328.8657 - val_recall: 1.0000
# Epoch 5/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -9179.8652 - recall: 1.0000 - val_loss: -14178.4287 - val_recall: 1.0000
# Epoch 6/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -16925.1934 - recall: 1.0000 - val_loss: -24097.6895 - val_recall: 1.0000
# Epoch 7/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -28034.0059 - recall: 1.0000 - val_loss: -37423.9180 - val_recall: 1.0000
# Epoch 8/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -42692.9258 - recall: 1.0000 - val_loss: -54513.6367 - val_recall: 1.0000
# Epoch 9/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -60838.1055 - recall: 1.0000 - val_loss: -75560.9922 - val_recall: 1.0000
# Epoch 10/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -84742.3516 - recall: 1.0000 - val_loss: -100994.8125 - val_recall: 1.0000
# Epoch 11/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -111432.9531 - recall: 1.0000 - val_loss: -130913.0078 - val_recall: 1.0000
# Epoch 12/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -142228.5469 - recall: 1.0000 - val_loss: -165788.7344 - val_recall: 1.0000
# Epoch 13/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -181982.5938 - recall: 1.0000 - val_loss: -205865.7969 - val_recall: 1.0000
# Epoch 14/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -221401.7031 - recall: 1.0000 - val_loss: -251178.2188 - val_recall: 1.0000
# Epoch 15/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -279227.8438 - recall: 1.0000 - val_loss: -301855.0938 - val_recall: 1.0000
# Epoch 16/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -321347.6250 - recall: 1.0000 - val_loss: -358053.9375 - val_recall: 1.0000
# Epoch 17/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -381228.4688 - recall: 1.0000 - val_loss: -420242.5938 - val_recall: 1.0000
# Epoch 18/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -453308.6875 - recall: 1.0000 - val_loss: -487974.2500 - val_recall: 1.0000
# Epoch 19/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -524072.6875 - recall: 1.0000 - val_loss: -561655.2500 - val_recall: 1.0000
# Epoch 20/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -600367.0625 - recall: 1.0000 - val_loss: -641428.2500 - val_recall: 1.0000
# Epoch 21/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -685130.0000 - recall: 1.0000 - val_loss: -726456.8125 - val_recall: 1.0000
# Epoch 22/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -773010.2500 - recall: 1.0000 - val_loss: -817990.6875 - val_recall: 1.0000
# Epoch 23/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -876226.6875 - recall: 1.0000 - val_loss: -915765.3750 - val_recall: 1.0000
# Epoch 24/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: -985996.9375 - recall: 1.0000 - val_loss: -1019892.6250 - val_recall: 1.0000
# Epoch 25/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -1064209.7500 - recall: 1.0000 - val_loss: -1130376.3750 - val_recall: 1.0000
# Epoch 26/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -1182618.7500 - recall: 1.0000 - val_loss: -1247206.3750 - val_recall: 1.0000
# Epoch 27/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -1290486.6250 - recall: 1.0000 - val_loss: -1370179.0000 - val_recall: 1.0000
# Epoch 28/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -1422819.5000 - recall: 1.0000 - val_loss: -1500181.8750 - val_recall: 1.0000
# Epoch 29/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -1599997.0000 - recall: 1.0000 - val_loss: -1637146.2500 - val_recall: 1.0000
# Epoch 30/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -1732857.3750 - recall: 1.0000 - val_loss: -1780111.0000 - val_recall: 1.0000
# Epoch 31/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -1863205.0000 - recall: 1.0000 - val_loss: -1930447.2500 - val_recall: 1.0000
# Epoch 32/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -2043086.5000 - recall: 1.0000 - val_loss: -2087902.5000 - val_recall: 1.0000
# Epoch 33/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -2240897.2500 - recall: 1.0000 - val_loss: -2251801.0000 - val_recall: 1.0000
# Epoch 34/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -2376971.0000 - recall: 1.0000 - val_loss: -2424331.0000 - val_recall: 1.0000
# Epoch 35/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -2595980.7500 - recall: 1.0000 - val_loss: -2603550.0000 - val_recall: 1.0000
# Epoch 36/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -2773236.7500 - recall: 1.0000 - val_loss: -2790481.0000 - val_recall: 1.0000
# Epoch 37/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -2899895.0000 - recall: 1.0000 - val_loss: -2984427.2500 - val_recall: 1.0000
# Epoch 38/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -3084156.7500 - recall: 1.0000 - val_loss: -3185586.5000 - val_recall: 1.0000
# Epoch 39/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -3338007.2500 - recall: 1.0000 - val_loss: -3395119.2500 - val_recall: 1.0000
# Epoch 40/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -3415555.7500 - recall: 1.0000 - val_loss: -3610816.0000 - val_recall: 1.0000
# Epoch 41/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -3763593.2500 - recall: 1.0000 - val_loss: -3835682.5000 - val_recall: 1.0000
# Epoch 42/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -4072652.5000 - recall: 1.0000 - val_loss: -4067968.7500 - val_recall: 1.0000
# Epoch 43/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -4262415.0000 - recall: 1.0000 - val_loss: -4308457.0000 - val_recall: 1.0000
# Epoch 44/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -4386059.0000 - recall: 1.0000 - val_loss: -4558124.0000 - val_recall: 1.0000
# Epoch 45/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -4745964.5000 - recall: 1.0000 - val_loss: -4815743.0000 - val_recall: 1.0000
# Epoch 46/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -4980729.0000 - recall: 1.0000 - val_loss: -5081607.5000 - val_recall: 1.0000
# Epoch 47/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -5338070.5000 - recall: 1.0000 - val_loss: -5354722.0000 - val_recall: 1.0000
# Epoch 48/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -5673804.0000 - recall: 1.0000 - val_loss: -5637327.0000 - val_recall: 1.0000
# Epoch 49/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -5839735.5000 - recall: 1.0000 - val_loss: -5928197.0000 - val_recall: 1.0000
# Epoch 50/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -6075775.0000 - recall: 1.0000 - val_loss: -6228053.5000 - val_recall: 1.0000
# Epoch 51/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -6551450.5000 - recall: 1.0000 - val_loss: -6537852.0000 - val_recall: 1.0000
# Epoch 52/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -6843323.0000 - recall: 1.0000 - val_loss: -6854776.5000 - val_recall: 1.0000
# Epoch 53/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -6984489.5000 - recall: 1.0000 - val_loss: -7180409.5000 - val_recall: 1.0000
# Epoch 54/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -7487478.5000 - recall: 1.0000 - val_loss: -7517402.0000 - val_recall: 1.0000
# Epoch 55/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -7878408.5000 - recall: 1.0000 - val_loss: -7863705.0000 - val_recall: 1.0000
# Epoch 56/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -8269132.0000 - recall: 1.0000 - val_loss: -8218801.0000 - val_recall: 1.0000
# Epoch 57/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -8688287.0000 - recall: 1.0000 - val_loss: -8582131.0000 - val_recall: 1.0000
# Epoch 58/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -8878680.0000 - recall: 1.0000 - val_loss: -8953740.0000 - val_recall: 1.0000
# Epoch 59/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -9320269.0000 - recall: 1.0000 - val_loss: -9339170.0000 - val_recall: 1.0000
# Epoch 60/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -9474747.0000 - recall: 1.0000 - val_loss: -9731400.0000 - val_recall: 1.0000
# Epoch 61/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -10151498.0000 - recall: 1.0000 - val_loss: -10134077.0000 - val_recall: 1.0000
# Epoch 62/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -10548586.0000 - recall: 1.0000 - val_loss: -10546746.0000 - val_recall: 1.0000
# Epoch 63/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -11035339.0000 - recall: 1.0000 - val_loss: -10967980.0000 - val_recall: 1.0000
# Epoch 64/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -11442238.0000 - recall: 1.0000 - val_loss: -11402406.0000 - val_recall: 1.0000
# Epoch 65/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -11699959.0000 - recall: 1.0000 - val_loss: -11846056.0000 - val_recall: 1.0000
# Epoch 66/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -12145459.0000 - recall: 1.0000 - val_loss: -12297226.0000 - val_recall: 1.0000
# Epoch 67/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -13055996.0000 - recall: 1.0000 - val_loss: -12761268.0000 - val_recall: 1.0000
# Epoch 68/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: -13431847.0000 - recall: 1.0000 - val_loss: -13237628.0000 - val_recall: 1.0000
# Epoch 69/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -13671983.0000 - recall: 1.0000 - val_loss: -13721683.0000 - val_recall: 1.0000
# Epoch 70/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -14208333.0000 - recall: 1.0000 - val_loss: -14214990.0000 - val_recall: 1.0000
# Epoch 71/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -15014885.0000 - recall: 1.0000 - val_loss: -14722543.0000 - val_recall: 1.0000
# Epoch 72/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -15463145.0000 - recall: 1.0000 - val_loss: -15242472.0000 - val_recall: 1.0000
# Epoch 73/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -15855300.0000 - recall: 1.0000 - val_loss: -15772992.0000 - val_recall: 1.0000
# Epoch 74/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -16184375.0000 - recall: 1.0000 - val_loss: -16312504.0000 - val_recall: 1.0000
# Epoch 75/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -16706555.0000 - recall: 1.0000 - val_loss: -16862810.0000 - val_recall: 1.0000
# Epoch 76/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -17490764.0000 - recall: 1.0000 - val_loss: -17421822.0000 - val_recall: 1.0000
# Epoch 77/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -18098874.0000 - recall: 1.0000 - val_loss: -17995878.0000 - val_recall: 1.0000
# Epoch 78/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -18493718.0000 - recall: 1.0000 - val_loss: -18580140.0000 - val_recall: 1.0000
# Epoch 79/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -19419258.0000 - recall: 1.0000 - val_loss: -19173712.0000 - val_recall: 1.0000
# Epoch 80/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -19835946.0000 - recall: 1.0000 - val_loss: -19785528.0000 - val_recall: 1.0000
# Epoch 81/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -20736680.0000 - recall: 1.0000 - val_loss: -20406078.0000 - val_recall: 1.0000
# Epoch 82/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -20942426.0000 - recall: 1.0000 - val_loss: -21036508.0000 - val_recall: 1.0000
# Epoch 83/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -22093326.0000 - recall: 1.0000 - val_loss: -21682086.0000 - val_recall: 1.0000
# Epoch 84/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -22357094.0000 - recall: 1.0000 - val_loss: -22340280.0000 - val_recall: 1.0000
# Epoch 85/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -23496884.0000 - recall: 1.0000 - val_loss: -23005856.0000 - val_recall: 1.0000
# Epoch 86/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -23905094.0000 - recall: 1.0000 - val_loss: -23687352.0000 - val_recall: 1.0000
# Epoch 87/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -24781886.0000 - recall: 1.0000 - val_loss: -24382256.0000 - val_recall: 1.0000
# Epoch 88/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -25594744.0000 - recall: 1.0000 - val_loss: -25092790.0000 - val_recall: 1.0000
# Epoch 89/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -25928464.0000 - recall: 1.0000 - val_loss: -25809976.0000 - val_recall: 1.0000
# Epoch 90/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -26517772.0000 - recall: 1.0000 - val_loss: -26536540.0000 - val_recall: 1.0000
# Epoch 91/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -27489560.0000 - recall: 1.0000 - val_loss: -27284774.0000 - val_recall: 1.0000
# Epoch 92/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -28106440.0000 - recall: 1.0000 - val_loss: -28037770.0000 - val_recall: 1.0000
# Epoch 93/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -28727624.0000 - recall: 1.0000 - val_loss: -28810736.0000 - val_recall: 1.0000
# Epoch 94/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -29451790.0000 - recall: 1.0000 - val_loss: -29594680.0000 - val_recall: 1.0000
# Epoch 95/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -30580060.0000 - recall: 1.0000 - val_loss: -30385464.0000 - val_recall: 1.0000
# Epoch 96/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -31023454.0000 - recall: 1.0000 - val_loss: -31194914.0000 - val_recall: 1.0000
# Epoch 97/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -32711380.0000 - recall: 1.0000 - val_loss: -32020788.0000 - val_recall: 1.0000
# Epoch 98/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -32750858.0000 - recall: 1.0000 - val_loss: -32853570.0000 - val_recall: 1.0000
# Epoch 99/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -33930452.0000 - recall: 1.0000 - val_loss: -33703012.0000 - val_recall: 1.0000
# Epoch 100/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -34817892.0000 - recall: 1.0000 - val_loss: -34565312.0000 - val_recall: 1.0000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: -35992180.0000 - recall: 1.0000
# Test Accuracy: 1.0
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Confusion Matrix:
# [[167   0]
#  [550   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.23      1.00      0.38       167
#            2       0.00      0.00      0.00       550
#
#     accuracy                           0.23       717
#    macro avg       0.12      0.50      0.19       717
# weighted avg       0.05      0.23      0.09       717
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import average_precision_score
print(f'Average Precision: {average_precision_score(y_test, y_pred)}')
# Out:
# Average Precision: 0.23291492329149233
